# %%
import os
STEPS = "./steps"
if not os.path.isdir(STEPS):
    os.mkdir(STEPS)

# %% [markdown]
# ### Build and Run Dataset Downloader

# %%
# !cd sub/paralells ; cargo build --release ; ./target/release/paralells --inputfolder "input (new data)" --outputfile result.csv
# Out:
# warning: unused import: `csv::StringRecord`
#  --> src/main.rs:2:5
#   |
# 2 | use csv::StringRecord;
#   |     ^^^^^^^^^^^^^^^^^
#   |
#   = note: `#[warn(unused_imports)]` on by default
#
# warning: unused import: `http::Request`
#  --> src/main.rs:3:5
#   |
# 3 | use http::Request;
#   |     ^^^^^^^^^^^^^
#
# warning: unused imports: `DirEntry`, `FileType`, and `self`
#   --> src/main.rs:9:16
#    |
#  9 |     fs::{self, DirEntry, File, FileType},
#    |                ^^^^^^^^        ^^^^^^^^
# 10 |     io::{Cursor, Read, Write},
# 11 |     path::{self, Path, PathBuf},
#    |            ^^^^
#
# warning: unused variable: `baseid`
#    --> src/main.rs:129:37
#     |
# 129 |             InputFile::Real { path, baseid } => Some(vec![path.clone()]),
#     |                                     ^^^^^^ help: try ignoring the field: `baseid: _`
#     |
#     = note: `#[warn(unused_variables)]` on by default
#
# warning: `paralells` (bin "paralells") generated 4 warnings (run `cargo fix --bin "paralells"` to apply 3 suggestions)
#     Finished `release` profile [optimized] target(s) in 0.21s

# %%
import cv2
import os
import numpy as np
from ultralytics import YOLO
INPUT_FOLDER = "./sub/paralells/steps/convertedtemp/" 

# 2. Set the path where the processed images will be saved.
OUTPUT_FOLDER = "processed_images" 

# 3. Define the target object classes the script should look for.
TARGET_CLASSES = ['banana', 'apple', 'avocado'] 

# 4. Define the final output size for the images.
FINAL_SIZE = (720, 720) 

# 5. Choose the model. 'yolov8n.pt' is small and fast, perfect for this.
MODEL_NAME = 'yolo11x-seg.pt' 


def preprocess_images():
    """
    Detects target objects, crops a 1:1 square around them, 
    resizes to a final size, and saves the results.
    """
    # Load the pre-trained YOLO model
    # The model will be downloaded automatically on the first run.
    print(f"Loading YOLO model: {MODEL_NAME}...")
    try:
        model = YOLO(MODEL_NAME)
    except Exception as e:
        print(f"Error loading model: {e}")
        print("Please ensure you have an internet connection for the first run.")
        return

    # Create the output directory if it doesn't exist
    os.makedirs(OUTPUT_FOLDER, exist_ok=True)
    print(f"Output will be saved to: {OUTPUT_FOLDER}")

    # List all files in the input folder
    if not os.path.exists(INPUT_FOLDER):
        print(f"Error: Input folder not found at '{INPUT_FOLDER}'")
        return
        
    image_files = [f for f in os.listdir(INPUT_FOLDER) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    if not image_files:
        print(f"No images found in '{INPUT_FOLDER}'. Please check the path.")
        return

    print(f"Found {len(image_files)} images to process.")
    processed_count = 0

    # Process each image file
    for filename in image_files:
        image_path = os.path.join(INPUT_FOLDER, filename)
        
        # Load the image
        image = cv2.imread(image_path)
        if image is None:
            print(f"--- Skipping {filename}: Could not read image file.")
            continue
        
        img_h, img_w = image.shape[:2]
        
        # Run YOLO detection
        results = model(image, verbose=False) # Set verbose to False to reduce console output
        
        best_detection = None
        highest_confidence = 0.0

        # Find the best detection among the target classes
        for result in results:
            if result.boxes is None:
                continue
            for box in result.boxes:
                class_id = int(box.cls[0])
                class_name = model.names[class_id]
                confidence = float(box.conf[0])
                
                if class_name in TARGET_CLASSES and confidence > highest_confidence:
                    highest_confidence = confidence
                    best_detection = box.xyxy[0].cpu().numpy() # [x1, y1, x2, y2]
        
        if best_detection is not None:
            # Calculate the center point of the detected object
            x1, y1, x2, y2 = best_detection
            center_x = int((x1 + x2) / 2)
            center_y = int((y1 + y2) / 2)

            # Calculate the largest possible square crop
            # The half-size is the minimum distance from the center to any edge
            dist_to_top = center_y
            dist_to_bottom = img_h - center_y
            dist_to_left = center_x
            dist_to_right = img_w - center_x
            
            half_size = int(min(dist_to_top, dist_to_bottom, dist_to_left, dist_to_right))

            # Define the crop box coordinates
            crop_x1 = center_x - half_size
            crop_y1 = center_y - half_size
            crop_x2 = center_x + half_size
            crop_y2 = center_y + half_size
            
            # Crop the image
            cropped_image = image[crop_y1:crop_y2, crop_x1:crop_x2]
            
            # Resize the cropped image to the final target size
            resized_image = cv2.resize(cropped_image, FINAL_SIZE, interpolation=cv2.INTER_AREA)
            
            # Save the processed image
            output_path = os.path.join(OUTPUT_FOLDER, filename)
            cv2.imwrite(output_path, resized_image)
            #print(f"-> Processed '{filename}' and saved to output folder.")
            processed_count += 1
        else:
            print(f"--- Skipping '{filename}': No target object found.")

    print(f"\nProcessing complete. Successfully processed {processed_count} out of {len(image_files)} images.")

# %% [markdown]
# Based on the previous step, find how many images succeeded in processing, and create a new CSV with only those only.

# %%
if __name__ == "__main__":
    preprocess_images()
# Out:
# Loading YOLO model: yolo11x-seg.pt...
# Output will be saved to: processed_images
# Found 4377 images to process.
# --- Skipping '43c3eced8be28cec61b39aafcc4544a2.png': No target object found.
# --- Skipping '7b1fc1148981ef69a29d6dddf3f98e8a.png': No target object found.
# --- Skipping 'fb7360a325c6ffb176850784613a55e5.png': No target object found.
# --- Skipping '9c8d8c66965d9d2f2a4db0596d1c887a.png': No target object found.
# --- Skipping 'ba562cbed9072e09f11791369790decd.png': No target object found.
# --- Skipping '09abf754af8e869d477fd49461f3bd43.png': No target object found.
# --- Skipping '544cf816635cfdcb6088915fb3ef5f13.png': No target object found.
# --- Skipping '2f9cef28ccab33a80922ff95551078f3.png': No target object found.
# --- Skipping '5d1f098ea651e1a298cb2beb02889eff.png': No target object found.
# --- Skipping 'cb20714c61e4576a5045e26dea0f1516.png': No target object found.
# --- Skipping '57e6cc8400d8cb9202f315845ebdce7d.png': No target object found.
# --- Skipping '027ffc85489d1163649ef9ffe7b501ff.png': No target object found.
# --- Skipping 'cabe2a30445b503f47fa64c43814faf6.png': No target object found.
# --- Skipping 'f18f7be997b605f7e2a5d48784e60f34.png': No target object found.
# --- Skipping '1e268d4cf936e1902c548a496876e621.png': No target object found.
# --- Skipping 'e454c087c7c0da9dddaa92716b1f6451.png': No target object found.
# --- Skipping 'eb36fa74e96d30910465019d7bca24b5.png': No target object found.
# --- Skipping 'c6a19e098bbc1a8af579cff2e3afedb9.png': No target object found.
# --- Skipping '1f9650d69c2ed7f4242e74ed95af4de7.png': No target object found.
# --- Skipping '8fdcc00ebf0384b30661908b71638ffe.png': No target object found.
# --- Skipping '48a1784c05c622333fb41289012abc63.png': No target object found.
# --- Skipping 'a143963e2ffaae840b9287004c63ee70.png': No target object found.
# --- Skipping 'ba344c3b82f06a1fc33139faa6e2c2bd.png': No target object found.
# --- Skipping '3144be9dab73bfe829aedcd312c867eb.png': No target object found.
# --- Skipping '029801033cced9e108d8467570c480bf.png': No target object found.
# --- Skipping 'c871cc63ccf4efcf1d7a3682e3c64209.png': No target object found.
# --- Skipping '8fcd042f1ffbf31172cc30af1be44eea.png': No target object found.
# --- Skipping 'be621aad188d464879d1a098a708991c.png': No target object found.
# --- Skipping '54c0c2a27fbbfedc69ebdce2bcae8571.png': No target object found.
# --- Skipping '7d775e0156b6f33d166a4ae98a2e3adb.png': No target object found.
# --- Skipping '0d222179aea5a582c35487824ba8f16f.png': No target object found.
# --- Skipping 'b71f8cd65978b11c3bedc5d9419543fe.png': No target object found.
# --- Skipping '01bab119fcef550c9e8185140b53fde3.png': No target object found.
# --- Skipping 'f8e77cb0365ee3c50416544e76e98219.png': No target object found.
# --- Skipping '37076be669b621a84cc6c8d30a2c1cd2.png': No target object found.
# --- Skipping 'df2ac5497586ea958713beb91a4d011f.png': No target object found.
# --- Skipping '6239975c67163130b9c37ef985dbe38b.png': No target object found.
# --- Skipping 'eb37b4b40d3408920a2693128d7fb987.png': No target object found.
# --- Skipping '80047ff4746221023ed3ccd4fbc9706b.png': No target object found.
# --- Skipping '1bec8a8eb0c9e39fa765bef5e1c104fd.png': No target object found.
# --- Skipping '773fa3f1c1d1f5f5a1801ee26c65b43a.png': No target object found.
# --- Skipping '173d2ddd91bd9fa40b17fb35f63f0700.png': No target object found.
# --- Skipping 'fc3389b1bcad413979b8a0d6f4005214.png': No target object found.
# --- Skipping '13431d95dcf066118fd8416a30bc38f6.png': No target object found.
# --- Skipping '58687ad92c0356474ff92334a801e417.png': No target object found.
# --- Skipping '3888a39774a601aff69181c61837be6a.png': No target object found.
# --- Skipping 'cafaf7f0771a632994f871f5285cc1fe.png': No target object found.
# --- Skipping 'b096c3d4d993ddf61fb4ae6aca634f12.png': No target object found.
# --- Skipping '50fcf5c8d6596c076428e858da41293b.png': No target object found.
# --- Skipping '7487132564e9c6a5c5f7fdc54384ec19.png': No target object found.
# --- Skipping 'e4b38195ffbe50fab9353a6e38f7e273.png': No target object found.
# --- Skipping 'bc4202e9ff6280de3ee68aabe77d97c6.png': No target object found.
# --- Skipping 'fa9267066c3106a551887308150976d2.png': No target object found.
# --- Skipping 'b2b870ff598839ca12860a3a8e45cde0.png': No target object found.
# --- Skipping 'f585ca39d49590a714189f14cdf410dc.png': No target object found.
# --- Skipping '924923a24a6458152723d3ea539d9f7e.png': No target object found.
# --- Skipping '55090949fef797f460bc666e474bbf9b.png': No target object found.
# --- Skipping 'bc1e1d1caf07103c372171160e072cb6.png': No target object found.
# --- Skipping 'a7954ba73f2891d324b69c17179dd94d.png': No target object found.
# --- Skipping 'a2def3619e0f25a1809309a942aca055.png': No target object found.
# --- Skipping '93e08e52a5086382383e0752e4691f0d.png': No target object found.
# --- Skipping '1877bf6ceb7d6a81e05eaae3e68f0cf5.png': No target object found.
# --- Skipping 'dd09f5d67046238cc51ea57eb01eb104.png': No target object found.
# --- Skipping 'db8ed18f691899d53c0ae4b490df4751.png': No target object found.
# --- Skipping '8aa99aee619377d4a0e2edeae01f0218.png': No target object found.
# --- Skipping '46588ca73fbd12f60ef5061d765f4a4f.png': No target object found.
# --- Skipping '63d05a42bfa144cf5ebed6b5156466c8.png': No target object found.
# --- Skipping 'b18c8e19fe73ddb43fce7898ec36d359.png': No target object found.
# --- Skipping '8d501bb2212a84b8bd32bd44413e1854.png': No target object found.
# --- Skipping 'c66256e61ea03a9d4015ef7e1a4661d7.png': No target object found.
# --- Skipping '7a4f4ad4c6076e207a63df9686ce8be1.png': No target object found.
# --- Skipping 'efcc03189459aaa1a421924a06a2716a.png': No target object found.
# --- Skipping 'c31a88a410c9069e8d6a70fb06648705.png': No target object found.
# --- Skipping 'dc281b0b140dade3230486bc09636c86.png': No target object found.
# --- Skipping '46a3771066db6baeab9e88134421bb15.png': No target object found.
# --- Skipping 'cf96afeb628f2f383035128fa1cf6ee1.png': No target object found.
# --- Skipping '409ab6ec0277575310117b801d527923.png': No target object found.
# --- Skipping '9d277a2e755dba1e92c6cf2ac05d3ff5.png': No target object found.
# --- Skipping 'd16f75bd7ce77dbb7a51e11ef691eea0.png': No target object found.
# --- Skipping 'a052c8126e848effc63e1134b159ab04.png': No target object found.
# --- Skipping '95adc0de84ea0dbe3b668bacc32244b1.png': No target object found.
# --- Skipping '7bcea61fd1dde25699006aaf151c6bce.png': No target object found.
# --- Skipping 'e1d850c1e18013fbf0a64f03da8fe48b.png': No target object found.
# --- Skipping 'f344baa09aaa8e91c2b66a950317cf7e.png': No target object found.
# --- Skipping '5294fa12b6f3861792e7d88a5295d34f.png': No target object found.
# --- Skipping '00b7df534f6f320a46f0dd272474a362.png': No target object found.
# --- Skipping '82383ddc1bbf41e4d9102e234b769163.png': No target object found.
# --- Skipping 'e29efeee62775f69fb614fbdde12b540.png': No target object found.
# --- Skipping '9a389ac610fee07ecbb5a5bdb0baac88.png': No target object found.
# --- Skipping 'b86497126d1a7be751a88491125e8a9e.png': No target object found.
# --- Skipping '80d130bbd9687b28900395b39f0ebc36.png': No target object found.
# --- Skipping '8ee9071b333a6b5558b0e70dffd212f7.png': No target object found.
# --- Skipping '58c27d9378e2f9d227ffb35ef6aa7049.png': No target object found.
# --- Skipping 'a251f34f8799e2b5543da8b3bcb38591.png': No target object found.
# --- Skipping '153996e9b884dbaed5b3efc7245f090b.png': No target object found.
# --- Skipping '07a9756aa6375e36f481c2827627d555.png': No target object found.
# --- Skipping '20a4261dc61666d0b8ab3e1b0e2c1093.png': No target object found.
# --- Skipping '9d7a91053886854a79e98a98acf0944b.png': No target object found.
# --- Skipping '1ae2cdfc64ea829fcc78f72deae41321.png': No target object found.
# --- Skipping 'f57756e55b18575cf8ad46a01b405155.png': No target object found.
# --- Skipping 'b5299957b58956ae0690d94899714e33.png': No target object found.
# --- Skipping '9dfc8b69e11505083d447351d75757b7.png': No target object found.
# --- Skipping 'b5e992e8b284b291ed15c153c6dd6d3f.png': No target object found.
# --- Skipping '0645d6c8703d6d226d5d57a7316810f2.png': No target object found.
# --- Skipping 'c54a935517a3c8d11d84a42095a4e218.png': No target object found.
# --- Skipping '48fed22ae3334854f2507e8e3f5f593e.png': No target object found.
# --- Skipping 'd19e479ad1fad6114815854f1edf4dba.png': No target object found.
# --- Skipping '5b6bf0d322f641f0ef93460dcd034929.png': No target object found.
# --- Skipping 'c24536c7e0d7546197667f75380f186b.png': No target object found.
# --- Skipping 'dcba93df6e02a5294453e82c2128e9e4.png': No target object found.
# --- Skipping '525317e7ac034e1f4ebee11564063795.png': No target object found.
# ...
# --- Skipping 'aedc907eb4209f64e434ad3dedf487c6.png': No target object found.
# --- Skipping '9080bd5683a5b00c2483ce683391db35.png': No target object found.
# --- Skipping 'f370405fb3437042557ea33e143d26b7.png': No target object found.
# --- Skipping '61d535c7265e93b39dfc2afd0001c913.png': No target object found.
# --- Skipping 'c4c0626203a8ee505bbd6fd11ac3ce00.png': No target object found.
# --- Skipping '9e5f440bc0b6a4aa604149b650d1fc7b.png': No target object found.
# --- Skipping 'f07501c2cc21dc417ce01ebbace97c7f.png': No target object found.
# --- Skipping '7f6c9c61bd64715d2e79e47c02cbab25.png': No target object found.
# --- Skipping '39651e1072a15948d68644cd619ca64d.png': No target object found.
# --- Skipping '73bb1e94ca1ac5ad5d1132bb0818acb6.png': No target object found.
# --- Skipping 'b07ba6f7f3faab6029dac2c9f8766f20.png': No target object found.
# --- Skipping '9edb0a5e5210d9cd3b867e1b85691cee.png': No target object found.
# --- Skipping '83366160fe8b3e5dec9d829e07529b39.png': No target object found.
# --- Skipping '706d7dc303c0953833d5dc362133bffe.png': No target object found.
# --- Skipping 'bf8954829df770975f302295cd639d74.png': No target object found.
# --- Skipping 'c99a43fa97031e8adb7951a310f2979b.png': No target object found.
# --- Skipping '8a7ae33aa80672c124151088326089d8.png': No target object found.
# --- Skipping '42f10104fc3d8585c07689f3eeb741cf.png': No target object found.
# --- Skipping '6d990419bc37370c2196cbb2bb5f7ac2.png': No target object found.
# --- Skipping '61909f7726d25438ad6076da89173837.png': No target object found.
# --- Skipping '8562ad867bf3be62a32d8e3090648d2e.png': No target object found.
# --- Skipping 'a0389ae44d52b1cd40a04f2362183a93.png': No target object found.
# --- Skipping '120902bd4cb579ff680ffc7240fad90b.png': No target object found.
# --- Skipping 'c4b54653b1756e4e9bd63d61be9777eb.png': No target object found.
# --- Skipping '06b8dfa3074097c0862cfca5ac75f804.png': No target object found.
# --- Skipping 'e5b23e788161e152e2f060deb3312eac.png': No target object found.
# --- Skipping 'a9b6c7fc1f2afabe0194312f37cbf84e.png': No target object found.
# --- Skipping '80b364c1913a6221b53c86a4d4bfd821.png': No target object found.
# --- Skipping '329d4d0c1f0f4597d3001e5f28864897.png': No target object found.
# --- Skipping '67ddd56c1494a684fe5d4b016fed94c2.png': No target object found.
# --- Skipping '55f19bf8594b869285d07c66a9f33979.png': No target object found.
# --- Skipping '5770c4e7d0277a7b987d2fe5680fabd3.png': No target object found.
# --- Skipping '2baa79671baedcd668d6b6495124acaf.png': No target object found.
# --- Skipping '363f8f68bec421bc4c0fda1255aff29a.png': No target object found.
# --- Skipping '9fd96211f31101fa6acf72eaadcd2722.png': No target object found.
# --- Skipping 'd257966e534357b2d9115886659890b4.png': No target object found.
# --- Skipping '85b025e6100f224edf5b11ea316f5504.png': No target object found.
# --- Skipping '79b4b7a316c61727a2b1383303b9d0f8.png': No target object found.
# --- Skipping '3d83789fd27f5eb80812b6325bb0d0fb.png': No target object found.
# --- Skipping '853a3abcbc38ddc7ab29594188cb2144.png': No target object found.
# --- Skipping '1bf173dd0c047b0a18b8e147ba7d394c.png': No target object found.
# --- Skipping 'b678151fbc2d4860abf38653181addc4.png': No target object found.
# --- Skipping '2a4ed92c93ae1be79db3f87a737cba7f.png': No target object found.
# --- Skipping 'f13761812bbcd63aeb746d436ba164d1.png': No target object found.
# --- Skipping '5a0d0e8ffe5ece90af22d145ef3b77c6.png': No target object found.
# --- Skipping 'd20816a46f5ccb875df8f8279821b356.png': No target object found.
# --- Skipping '18f39bba4e22bf04b83df08f03a0d1f4.png': No target object found.
# --- Skipping '89401432be678b33ef2fcb389f56b972.png': No target object found.
# --- Skipping 'e45862f60c70ea817947cd60cf3ba810.png': No target object found.
# --- Skipping '748caf6443cf03be328c94af55ebbf56.png': No target object found.
# --- Skipping '3bae4a1937b0f2170378b3706ae6e021.png': No target object found.
# --- Skipping '7cd319129e5755450a80c32ab00eeb43.png': No target object found.
# --- Skipping '0385c7e9362e0ce45f5c3bb12ede31c9.png': No target object found.
# --- Skipping '8724533a3320baf627aa1842c0252d88.png': No target object found.
# --- Skipping 'a0f9f528b6d77a38a3e4dc5234ca85d2.png': No target object found.
# --- Skipping 'c3951d00eecca205f2956d79a73ae3a1.png': No target object found.
# --- Skipping 'dc48ed808cbabdd41a6f8aa9e8ae74df.png': No target object found.
# --- Skipping '2b7586974fa73b1a812a589160a065bc.png': No target object found.
# --- Skipping '416915e5022b2a1f734b7be118fb61b4.png': No target object found.
# --- Skipping 'b0a0a6354bb092127889d14a11c053e1.png': No target object found.
# --- Skipping '3418f9b5f737c961f3ea8ab20bcbcfb2.png': No target object found.
# --- Skipping '08e2bda812de2e7476ee37d801525615.png': No target object found.
# --- Skipping 'ca64dd237476cf21058ff4817238da31.png': No target object found.
# --- Skipping 'fa8dce89d907b66d7a8a924bdcdf3b16.png': No target object found.
# --- Skipping '9e4fa59cf8d5b978167b5dcee342b830.png': No target object found.
# --- Skipping '56a52210c7367cbda742baa82c3b5c36.png': No target object found.
# --- Skipping 'e87a256dce175295f397b7043274d6c0.png': No target object found.
# --- Skipping '7725673cbf29b1ee1c0bb63d3d09462f.png': No target object found.
# --- Skipping 'fa4afc51c0069aee683453e65317e6cc.png': No target object found.
# --- Skipping '0f13682d6f8aeda240acb2b6b46e59d7.png': No target object found.
# --- Skipping '8a0fa2d3fac0fd75f11c432c6fd507c3.png': No target object found.
# --- Skipping '3b9a3ad8467f68699e099f8b191ebdd9.png': No target object found.
# --- Skipping 'b415defd21028935a2e631cd8dd02bb8.png': No target object found.
# --- Skipping '43d5b2f401dbb9b489f96aa0e8bf1eab.png': No target object found.
# --- Skipping 'e6094ae136273d2aaa55b6effd432d91.png': No target object found.
# --- Skipping 'bc691a79062cc14909a10690b6d79a37.png': No target object found.
# --- Skipping '613783a2832db9150243135df6aeb1aa.png': No target object found.
# --- Skipping 'cae017969c46e0753f5fdc3032240cee.png': No target object found.
# --- Skipping 'ee80e1a5b35d0a2608892b026175eacf.png': No target object found.
# --- Skipping 'c27bdfbf925c08a8476e31350b2e1583.png': No target object found.
# --- Skipping 'c5d06ebde935d1ff11ac8d502c8e8085.png': No target object found.
# --- Skipping '5cd8d5a3752ac2a08ac97da382be35ba.png': No target object found.
# --- Skipping '2cc60882365d46233e037ac7ab505385.png': No target object found.
# --- Skipping '776b24daad08ff9dd719f758d55fc02f.png': No target object found.
# --- Skipping '6d27696876b996659b0a62a862cceb0b.png': No target object found.
# --- Skipping '24a204b72db7fca348c7e5f196b61171.png': No target object found.
# --- Skipping '61db91814b3467b921f6383123337fac.png': No target object found.
# --- Skipping '9bc96ce26f60428feecdd1c435f1f4b9.png': No target object found.
# --- Skipping '812cac04858c1aa44db653291a4baec9.png': No target object found.
# --- Skipping 'a5de31d89d46ef3f3fd9c0000a7d46af.png': No target object found.
# --- Skipping 'd149f9b68b05c75664b8bf3deea0d940.png': No target object found.
# --- Skipping 'bbbbe1b2960bf12d3a1b69a66027d43b.png': No target object found.
# --- Skipping 'bee35850d051b3ea9db8d0292a93cb06.png': No target object found.
# --- Skipping '00f7ddc50f199ba3754f36535f227472.png': No target object found.
# --- Skipping '7e6e35221968bc7875c1721493e49a60.png': No target object found.
# --- Skipping '4e54a6259fa2051a82ff1f4c85b62fd6.png': No target object found.
# --- Skipping '16767c8298aecf748fd52f23b8444dea.png': No target object found.
# --- Skipping '24f7c38d5d9185574983af8ff8b19613.png': No target object found.
# --- Skipping '68f568b7b581c3bd2f1f12256cea41e0.png': No target object found.
# --- Skipping 'c222abd2f4dcf88c3f55b6bffec50480.png': No target object found.
# --- Skipping '3a1a1585f27fff5963e3ef4182e0ce66.png': No target object found.
# --- Skipping '029fd37e2d8a4a7cd42325d51bc444c6.png': No target object found.
# --- Skipping '8bc47d669f101ec24bfe76e01fd8273f.png': No target object found.
# --- Skipping '35919a1e8b1dd43e7f4b203eeff8dcc0.png': No target object found.
# --- Skipping '141a2898549c5a1ac5d6e71c218bcd11.png': No target object found.
# --- Skipping '2b60f9cf216d6f1a5ac158947b625f45.png': No target object found.
# --- Skipping 'c92182861fdfa0109b74a42737e6a2a0.png': No target object found.
# --- Skipping 'e5ce9f2a7a43f5d826db5f0ecadf16ee.png': No target object found.
# --- Skipping 'c827dfaf50e9f727566e902649c5fe02.png': No target object found.
# --- Skipping '7c80c4f804f97f5b84a528fd0380ad38.png': No target object found.
# --- Skipping '24e455d55ffff9c6e3c65984dc4559ee.png': No target object found.
# --- Skipping 'b40a6f5bd5bfb236ee00e45ef0cc284c.png': No target object found.
# --- Skipping '21efdcb7f4b57e1652fa770f3a6f356e.png': No target object found.
# --- Skipping '431128db6b19ddf90082fd108dbe1a45.png': No target object found.
# --- Skipping '54583b5b4de703cc29748a1df542fe84.png': No target object found.
# --- Skipping '3fec0f6274996b8b1b7339c454622427.png': No target object found.
# --- Skipping '08d8c49de42eaebcc267b43c5bafa591.png': No target object found.
# --- Skipping '566a5c0cdd1ab0fb4c6527ddef395e85.png': No target object found.
# --- Skipping 'f5e19ac02692f5834e145e04fa45ce3a.png': No target object found.
# --- Skipping 'a7d25e1cc838ac0a9b1d25e20986162d.png': No target object found.
# --- Skipping 'e268e14571484394f266020e40be9d1c.png': No target object found.
# --- Skipping '5e2b4a70a1d37fbf0cc27cdc3a35408a.png': No target object found.
# --- Skipping '0414dfce5c9031cff26de3eee1f31d7b.png': No target object found.
# --- Skipping '385db994447ff874997225004c7473b6.png': No target object found.
# --- Skipping '0eac5abbd81dc638ad4cb04a413adc17.png': No target object found.
# --- Skipping '9e5a981104544f16162cffca25b0adae.png': No target object found.
# --- Skipping 'a23a7d2e6180c081b8ce58401e6dbae7.png': No target object found.
# --- Skipping '9e049d5245ac407587047a6bc24f99dd.png': No target object found.
#
# Processing complete. Successfully processed 3463 out of 4377 images.

# %%
CSV_FILE = "./sub/paralells/result.csv"
PROCESSED_FOLDER = "./processed_images/"

import os
import csv

def filter_csv_by_processed_images(input_csv, processed_folder, output_csv):
    """
    Reads input_csv, keeps only rows where the image (first column) exists in processed_folder,
    and writes the filtered rows to output_csv.
    """
    processed_images = set(os.listdir(processed_folder))
    filtered_rows = []

    with open(input_csv, newline='') as infile:
        reader = csv.reader(infile)
        header = next(reader)
        filtered_rows.append(header)
        for row in reader:
            if row and row[0] in processed_images:
                filtered_rows.append(row)

    with open(output_csv, 'w', newline='') as outfile:
        writer = csv.writer(outfile)
        writer.writerows(filtered_rows)
    print(f"Filtered CSV saved to {output_csv} with {len(filtered_rows)-1} entries.")

filter_csv_by_processed_images("./sub/paralells/result.csv", "./processed_images/", "./filtered_result.csv")
# Out:
# Filtered CSV saved to ./filtered_result.csv with 3484 entries.

# %%
# %run createDerivation.py
filtered_df = pd.read_csv("/sub/paralells/result.csv")
def keep_all(path): return True
def identity_map(path):
    with open(path, "rb") as f: return f.read()
default_variation_csv = create_dataset_variation(filtered_df, keep_all, identity_map, variation_tag="identity")
print(default_variation_csv)

def unsharp_mask_map(path: str, gamma=0) -> bytes:
    """
    Apply unsharp mask to the image at 'path' and return the processed image bytes.
    - alpha: weight of the original image
    - beta: weight of the blurred image (negative for sharpening)
    - gamma: scalar added to each sum
    """
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Could not read image at {path}")
    blurred = cv2.GaussianBlur(img, (5, 5), sigmaX=3, sigmaY=3)
    weight = 1.5
    sharpened = cv2.addWeighted(img, 1 + weight, blurred, -weight, gamma)
    _, buf = cv2.imencode('.jpg', sharpened)
    return buf.tobytes()
unsharp_variation_csv = create_dataset_variation(filtered_df, keep_all, unsharp_mask_map, variation_tag="unsharp")
print(unsharp_variation_csv)

# Build a YOLO-based preprocessing + filtering pipeline using create_dataset_variation

# Choose base dataset to (re)process
target_df = pd.read_csv(unsharp_variation_csv)

# Ensure required globals exist
assert 'MODEL_NAME' in globals(), "MODEL_NAME not defined (from earlier YOLO cell)."
assert 'FINAL_SIZE' in globals(), "FINAL_SIZE not defined (from earlier YOLO cell)."
assert 'TARGET_CLASSES' in globals(), "TARGET_CLASSES not defined (from earlier YOLO cell)."
assert 'create_dataset_variation' in globals(), "create_dataset_variation not available."

print(f"Loading YOLO model: {MODEL_NAME} ...")
try:
    _yolo_model = YOLO(MODEL_NAME)
except Exception as e:
    raise RuntimeError(f"Failed to load YOLO model '{MODEL_NAME}': {e}")

_target_classes = set(TARGET_CLASSES)

def _best_square_crop_from_results(image, results, names):
    img_h, img_w = image.shape[:2]
    best_detection = None
    highest_conf = -1.0

    for result in results:
        if result.boxes is None:
            continue
        for box in result.boxes:
            class_id = int(box.cls[0])
            class_name = names.get(class_id, str(class_id))
            if class_name not in _target_classes:
                continue
            conf = float(box.conf[0])
            if conf > highest_conf:
                highest_conf = conf
                x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().tolist()
                best_detection = (x1, y1, x2, y2)

    if best_detection is None:
        return None

    x1, y1, x2, y2 = best_detection
    cx = int((x1 + x2) / 2)
    cy = int((y1 + y2) / 2)
    dist_to_top = cy
    dist_to_bottom = img_h - cy
    dist_to_left = cx
    dist_to_right = img_w - cx
    half_size = int(min(dist_to_top, dist_to_bottom, dist_to_left, dist_to_right))
    if half_size <= 0:
        return None
    return (
        max(0, cx - half_size),
        max(0, cy - half_size),
        min(img_w, cx + half_size),
        min(img_h, cy + half_size),
    )

# Precompute crop regions for all valid images in base_df
print(f"Scanning {len(target_df)} images for target objects: {sorted(_target_classes)}")
_crop_index = {}
_skipped = 0
for i, row in target_df.iterrows():
    p = row["file_path"]
    if not isinstance(p, str) or not os.path.isfile(p):
        _skipped += 1
        continue
    img = cv2.imread(p)
    if img is None:
        _skipped += 1
        continue
    try:
        results = _yolo_model(img, verbose=False)
        crop_box = _best_square_crop_from_results(img, results, _yolo_model.names)
        if crop_box is not None:
            _crop_index[p] = crop_box
    except Exception:
        _skipped += 1

print(f"Found {len(_crop_index)} images with target detections. Skipped: {_skipped}")

def yolo_filter_fn(path: str) -> bool:
    return path in _crop_index

def yolo_crop_map_fn(path: str) -> bytes:
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Could not read image: {path}")
    x1, y1, x2, y2 = _crop_index.get(path, (0, 0, img.shape[1], img.shape[0]))
    cropped = img[y1:y2, x1:x2]
    if cropped.size == 0:
        cropped = img  # fallback to original if something went wrong
    resized = cv2.resize(cropped, FINAL_SIZE, interpolation=cv2.INTER_AREA)
    ok, buf = cv2.imencode(".png", resized)
    if not ok:
        raise RuntimeError("Failed to encode cropped image.")
    return buf.tobytes()

variation_tag = f"yolo_crop_{MODEL_NAME}_to_{FINAL_SIZE[0]}x{FINAL_SIZE[1]}"
filtered2_path = create_dataset_variation(target_df, yolo_filter_fn, yolo_crop_map_fn, variation_tag=variation_tag)
print("New variation CSV:", filtered2_path)
f = open("final_variation.txt", "w")
f.write(filtered2_path)
f.close()

# %% [markdown]
# ## EDA

# %%
import pandas as pd

import matplotlib.pyplot as plt

# Read the filtered CSV
filtered_df = pd.read_csv("./filtered_result.csv")

# Assuming the class label is in a column named 'class' or similar
# If not, print columns to inspect
print("Columns:", filtered_df.columns)

# Replace 'class' with the actual column name if different
class_col = 'class_name' if 'class_name' in filtered_df.columns else filtered_df.columns[-1]

# Count occurrences of each class
class_counts = filtered_df[class_col].value_counts()

# Pie chart of class distribution with numbers shown
def make_autopct(values):
    def my_autopct(pct):
        total = int(values.sum())
        val = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({val})'
    return my_autopct

plt.figure(figsize=(6, 6))
class_counts.plot(
    kind='pie',
    autopct=make_autopct(class_counts),
    startangle=90,
    legend=False
)
plt.title('Class Distribution (Pie Chart) for filtered data')
plt.ylabel('')
plt.axis('equal')  # keep pie circular
plt.show()

unfiltered_df = pd.read_csv("./sub/paralells/result.csv")
# Assuming the class label is in a column named 'class' or similar
# If not, print columns to inspect
print("Columns in unfiltered data:", unfiltered_df.columns)
class_col_unfiltered = 'class_name' if 'class_name' in unfiltered_df.columns else unfiltered_df.columns[-1]
class_counts_unfiltered = unfiltered_df[class_col_unfiltered].value_counts()
plt.figure(figsize=(6, 6))
class_counts_unfiltered.plot(
    kind='pie',
    autopct=make_autopct(class_counts_unfiltered),
    startangle=90,
    legend=False
)
plt.title('Class Distribution (Pie Chart) for unfiltered data')
plt.ylabel('')
plt.axis('equal')  # keep pie circular
plt.show()
# Out:
# Columns: Index(['id', 'class_name', 'file_path', 'resolution'], dtype='object')
# Columns in unfiltered data: Index(['id', 'class_name', 'file_path', 'resolution'], dtype='object')

# %%
#
# DATASET STRUCTURE:
# 1st column: image ID
# 2nd column: class label (e.g., 'banana', 'apple', 'avocado')
# 3rd column: absolute path to the image file
# 4th column: resolution in "WIDTHxHEIGHT" format (e.g., "1920x1080") (THIS DOES NOT CHANGE AFTER PROCESSING)

# %% [markdown]
# # Image Resolution

# %%
# Display the image sizes before and after processing
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
import numpy as np
# Read the filtered CSV as the resolution doesnt change after processing, and find classes where the 2nd column contains "google"
filtered_df2 = pd.read_csv("./filtered_result.csv")
filtered_df2 = filtered_df2[filtered_df2.iloc[:, 1].str.contains("google", case=False, na=False)]
# Extract original resolutions from the 4th column
resolutions = filtered_df2.iloc[:, 3].dropna().tolist()
widths, heights = zip(*(map(int, res.split('x')) for res in resolutions if 'x' in res))
# Plot original resolutions as scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(widths, heights, alpha=0.5)
plt.title('Original Image Resolutions for scraped images')
plt.xlabel('Width (pixels)')
plt.ylabel('Height (pixels)')
plt.grid(True)
plt.show()

# Read the filtered CSV as the resolution doesnt change after processing, and find classes where the 2nd column does not contain "google"
filtered_df2 = pd.read_csv("./filtered_result.csv")
filtered_df2 = filtered_df2[~filtered_df2.iloc[:, 1].str.contains("google", case=False, na=False)]
# Extract original resolutions from the 4th column
resolutions = filtered_df2.iloc[:, 3].dropna().tolist()
widths, heights = zip(*(map(int, res.split('x')) for res in resolutions if 'x' in res))
# Plot original resolutions as scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(widths, heights, alpha=0.5)
plt.title('Original Image Resolutions for non-scraped images')
plt.xlabel('Width (pixels)')
plt.ylabel('Height (pixels)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Brightness and Bluriness

# %%
from concurrent.futures import ThreadPoolExecutor
from typing import Tuple, Optional
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def compute_image_quality_by_class(
    df,
    class_column: Optional[str] = None,
    path_column: str = "file_path",
    max_workers: Optional[int] = None,
    dataset_name: str = "Dataset",
) -> Tuple[Optional[pd.DataFrame], Optional[pd.DataFrame]]:
    """
    Compute Laplacian variance (focus/blur measure) and average brightness for each image,
    aggregate per class, and draw summary plots. Runs image processing in parallel.

    Returns:
      - per_image_df: DataFrame with columns [class_column, laplacian_variance, avg_brightness]
      - summary_df: Aggregated stats per class with mean/std and counts
    """
    if class_column is None:
        # Use existing global `class_col` variable
        class_column = class_col

    # Collect valid (path, class) pairs
    pairs = []
    for _, row in df.iterrows():
        p = row[path_column]
        c = row[class_column]
        if isinstance(p, str) and os.path.isfile(p):
            pairs.append((p, c))

    if not pairs:
        print("No valid image paths found.")
        return None, None

    def _worker(args):
        path, cls = args
        try:
            img = cv2.imread(path, cv2.IMREAD_COLOR)
            if img is None:
                return None
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            lap_var = float(cv2.Laplacian(gray, cv2.CV_64F).var())
            brightness = float(gray.mean())
            return (cls, lap_var, brightness)
        except Exception:
            return None

    max_workers = max_workers or min(32, (os.cpu_count() or 4))
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as ex:
        for r in ex.map(_worker, pairs):
            if r is not None:
                results.append(r)

    if not results:
        print("No images processed successfully.")
        return None, None

    per_image_df = pd.DataFrame(results, columns=[class_column, "laplacian_variance", "avg_brightness"])

    summary = (
        per_image_df.groupby(class_column)
        .agg(
            count=("laplacian_variance", "count"),
            lap_var_mean=("laplacian_variance", "mean"),
            lap_var_std=("laplacian_variance", "std"),
            brightness_mean=("avg_brightness", "mean"),
            brightness_std=("avg_brightness", "std"),
        )
        .sort_values("count", ascending=False)
    )
    print(summary)
    # Plot: blur metric and brightness with error bars
    classes = summary.index.tolist()

    fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=False)

    axes[0].bar(classes, summary["lap_var_mean"], yerr=summary["lap_var_std"], capsize=3, color="#4C78A8")
    axes[0].set_title(f"Blur (Laplacian Variance) by Class - {dataset_name}")
    axes[0].set_ylabel("Laplacian variance (higher = sharper)")
    axes[0].grid(axis="y", alpha=0.3)
    for tick in axes[0].get_xticklabels():
        tick.set_rotation(45)
        tick.set_horizontalalignment("right")
    # Annotate counts on top
    for i, (cls, row) in enumerate(summary.iterrows()):
        axes[0].text(i, row["lap_var_mean"], f"n={int(row['count'])}", ha="center", va="bottom", fontsize=8)

    axes[1].bar(classes, summary["brightness_mean"], yerr=summary["brightness_std"], capsize=3, color="#F58518")
    axes[1].set_title(f"Average Brightness by Class - {dataset_name}")
    axes[1].set_ylabel("Brightness (0-255)")
    axes[1].grid(axis="y", alpha=0.3)
    for tick in axes[1].get_xticklabels():
        tick.set_rotation(45)
        tick.set_horizontalalignment("right")

    plt.tight_layout()
    plt.show()

    print(f"Processed {len(per_image_df)} images across {summary.shape[0]} classes using {max_workers} workers.")
    return per_image_df, summary

filtered_df2 = pd.read_csv("./filtered_result.csv")
filtered_df2 = filtered_df2[~filtered_df2.iloc[:, 1].str.contains("google", case=False, na=False)]

# Example usage on filtered and unfiltered datasets:
per_image_df_filtered, summary_filtered = compute_image_quality_by_class(
    filtered_df2, class_column=class_col, path_column="file_path", dataset_name="Filtered"
)

filtered_df2 = pd.read_csv("./filtered_result.csv")
filtered_df2 = filtered_df2[filtered_df2.iloc[:, 1].str.contains("google", case=False, na=False)]

# Example usage on filtered and unfiltered datasets:
per_image_df_filtered, summary_filtered = compute_image_quality_by_class(
    filtered_df2, class_column=class_col, path_column="file_path", dataset_name="Filtered"
)

# Uncomment to run on unfiltered as well (heavier):
# per_image_df_unfiltered, summary_unfiltered = compute_image_quality_by_class(
#     unfiltered_df, class_column=class_col_unfiltered, path_column="file_path", dataset_name="Unfiltered"
# )
# Out:
#                        count  lap_var_mean  lap_var_std  brightness_mean  \
# class_name
# avocado_firm_self       1439     59.253245    56.316153       110.605884
# avocado_breaking_self    814     63.606296    43.553820       109.568084
# avocado_ripe_self        772     60.724633    46.140519       108.415843
# banana_day1_self          50     51.917928    62.442801       128.677531
# banana_day2_self          50     17.588865    17.452228       127.599603
# banana_day3_self          50     50.805139    39.542031       127.980576
# banana_day4_self          49     35.044515    18.499170       131.153691
# banana_day5_self          49     54.764076    29.722959       127.890027
# banana_day6_self          48     49.450827    33.555011       125.752227
# banana_day7_self          47     53.732976    30.178905       124.559703
#
#                        brightness_std
# class_name
# avocado_firm_self           10.598701
# avocado_breaking_self       12.073517
# avocado_ripe_self           10.604733
# banana_day1_self            17.275906
# banana_day2_self            24.110422
# banana_day3_self            21.833481
# banana_day4_self            19.024309
# banana_day5_self            20.888736
# banana_day6_self            23.747512
# banana_day7_self            23.520256
# Processed 3368 images across 10 classes using 12 workers.
#                        count  lap_var_mean  lap_var_std  brightness_mean  \
# class_name
# alpukat_unripe_google     59    847.091118   819.545723       149.032543
# alpukat_ripe_google       57    857.646089   867.676126       153.688952
#
#                        brightness_std
# class_name
# alpukat_unripe_google       41.050147
# alpukat_ripe_google         45.787059
# Processed 116 images across 2 classes using 12 workers.

# %%
# Out:
# Wrote 3484 rows to /home/fadhlan/Normal2/DeepLearningRepo/steps/variations/var_7b6f92977df96b6d/7b6f92977df96b6d.csv (variation 7b6f92977df96b6d)
# /home/fadhlan/Normal2/DeepLearningRepo/steps/variations/var_7b6f92977df96b6d/7b6f92977df96b6d.csv

# %%
# Out:
# Wrote 3484 rows to /home/fadhlan/Normal2/DeepLearningRepo/steps/variations/var_2a77ef5c09c14370/2a77ef5c09c14370.csv (variation 2a77ef5c09c14370)
# /home/fadhlan/Normal2/DeepLearningRepo/steps/variations/var_2a77ef5c09c14370/2a77ef5c09c14370.csv

# %%
# %run createDerivation.py
filtered_df = pd.read_csv("./filtered_result.csv")
def keep_all(path): return True
def identity_map(path):
    with open(path, "rb") as f: return f.read()
default_variation_csv = create_dataset_variation(filtered_df, keep_all, identity_map, variation_tag="identity")
print(default_variation_csv)

def unsharp_mask_map(path: str, gamma=0) -> bytes:
    """
    Apply unsharp mask to the image at 'path' and return the processed image bytes.
    - alpha: weight of the original image
    - beta: weight of the blurred image (negative for sharpening)
    - gamma: scalar added to each sum
    """
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Could not read image at {path}")
    blurred = cv2.GaussianBlur(img, (5, 5), sigmaX=3, sigmaY=3)
    weight = 1.5
    sharpened = cv2.addWeighted(img, 1 + weight, blurred, -weight, gamma)
    _, buf = cv2.imencode('.jpg', sharpened)
    return buf.tobytes()
unsharp_variation_csv = create_dataset_variation(filtered_df, keep_all, unsharp_mask_map, variation_tag="unsharp")
print(unsharp_variation_csv)

# Build a YOLO-based preprocessing + filtering pipeline using create_dataset_variation

# Choose base dataset to (re)process
target_df = pd.read_csv(unsharp_variation_csv)

# Ensure required globals exist
assert 'MODEL_NAME' in globals(), "MODEL_NAME not defined (from earlier YOLO cell)."
assert 'FINAL_SIZE' in globals(), "FINAL_SIZE not defined (from earlier YOLO cell)."
assert 'TARGET_CLASSES' in globals(), "TARGET_CLASSES not defined (from earlier YOLO cell)."
assert 'create_dataset_variation' in globals(), "create_dataset_variation not available."

print(f"Loading YOLO model: {MODEL_NAME} ...")
try:
    _yolo_model = YOLO(MODEL_NAME)
except Exception as e:
    raise RuntimeError(f"Failed to load YOLO model '{MODEL_NAME}': {e}")

_target_classes = set(TARGET_CLASSES)

def _best_square_crop_from_results(image, results, names):
    img_h, img_w = image.shape[:2]
    best_detection = None
    highest_conf = -1.0

    for result in results:
        if result.boxes is None:
            continue
        for box in result.boxes:
            class_id = int(box.cls[0])
            class_name = names.get(class_id, str(class_id))
            if class_name not in _target_classes:
                continue
            conf = float(box.conf[0])
            if conf > highest_conf:
                highest_conf = conf
                x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().tolist()
                best_detection = (x1, y1, x2, y2)

    if best_detection is None:
        return None

    x1, y1, x2, y2 = best_detection
    cx = int((x1 + x2) / 2)
    cy = int((y1 + y2) / 2)
    dist_to_top = cy
    dist_to_bottom = img_h - cy
    dist_to_left = cx
    dist_to_right = img_w - cx
    half_size = int(min(dist_to_top, dist_to_bottom, dist_to_left, dist_to_right))
    if half_size <= 0:
        return None
    return (
        max(0, cx - half_size),
        max(0, cy - half_size),
        min(img_w, cx + half_size),
        min(img_h, cy + half_size),
    )

# Precompute crop regions for all valid images in base_df
print(f"Scanning {len(target_df)} images for target objects: {sorted(_target_classes)}")
_crop_index = {}
_skipped = 0
for i, row in target_df.iterrows():
    p = row["file_path"]
    if not isinstance(p, str) or not os.path.isfile(p):
        _skipped += 1
        continue
    img = cv2.imread(p)
    if img is None:
        _skipped += 1
        continue
    try:
        results = _yolo_model(img, verbose=False)
        crop_box = _best_square_crop_from_results(img, results, _yolo_model.names)
        if crop_box is not None:
            _crop_index[p] = crop_box
    except Exception:
        _skipped += 1

print(f"Found {len(_crop_index)} images with target detections. Skipped: {_skipped}")

def yolo_filter_fn(path: str) -> bool:
    return path in _crop_index

def yolo_crop_map_fn(path: str) -> bytes:
    img = cv2.imread(path)
    if img is None:
        raise ValueError(f"Could not read image: {path}")
    x1, y1, x2, y2 = _crop_index.get(path, (0, 0, img.shape[1], img.shape[0]))
    cropped = img[y1:y2, x1:x2]
    if cropped.size == 0:
        cropped = img  # fallback to original if something went wrong
    resized = cv2.resize(cropped, FINAL_SIZE, interpolation=cv2.INTER_AREA)
    ok, buf = cv2.imencode(".png", resized)
    if not ok:
        raise RuntimeError("Failed to encode cropped image.")
    return buf.tobytes()

variation_tag = f"yolo_crop_{MODEL_NAME}_to_{FINAL_SIZE[0]}x{FINAL_SIZE[1]}"
filtered2_path = create_dataset_variation(target_df, yolo_filter_fn, yolo_crop_map_fn, variation_tag=variation_tag)
print("New variation CSV:", filtered2_path)
f = open("final_variation.txt", "w")
f.write(filtered2_path)
f.close()
# Out:
# Loading YOLO model: yolo11x-seg.pt ...
# Scanning 3484 images for target objects: ['apple', 'avocado', 'banana']
# Found 2962 images with target detections. Skipped: 0
# Wrote 2975 rows to /home/fadhlan/Normal2/DeepLearningRepo/steps/variations/var_5118e532c6e15885/5118e532c6e15885.csv (variation 5118e532c6e15885)
# New variation CSV: /home/fadhlan/Normal2/DeepLearningRepo/steps/variations/var_5118e532c6e15885/5118e532c6e15885.csv

# %%
class_col = 'class_name' if 'class_name' in filtered_df.columns else filtered_df.columns[-1]
final_df = pd.read_csv(filtered2_path)
# Count occurrences of each class
class_counts = filtered_df[class_col].value_counts()

# Pie chart of class distribution with numbers shown
def make_autopct(values):
    def my_autopct(pct):
        total = int(values.sum())
        val = int(round(pct * total / 100.0))
        return f'{pct:.1f}%\n({val})'
    return my_autopct

plt.figure(figsize=(6, 6))
class_counts.plot(
    kind='pie',
    autopct=make_autopct(class_counts),
    startangle=90,
    legend=False
)
plt.title('Class Distribution (Pie Chart) for final data')
plt.ylabel('')
plt.axis('equal')  # keep pie circular
plt.show()
